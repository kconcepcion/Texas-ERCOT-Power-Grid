# %%
# %matplotlib notebook

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Energy = [416, 377, 403]
Electricity = [154, 99, 150]

n=3
r = np.arange(n)
width = 0.25


plt.bar(r, Energy, color = 'b',
		width = width, edgecolor = 'black',
		label='Total Energy')
plt.bar(r + width, Electricity, color = 'g',
		width = width, edgecolor = 'black',
		label='Monthly Electricity')

plt.xlabel("State")
plt.ylabel("Cost ($)")
plt.title("Electricity and Energy Cost 2022")

# plt.grid(linestyle='--')
plt.xticks(r + width/2,['Texas','New Mexico','Arizona'])
plt.legend(loc='upper center')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="622">

# %%
plt.xlim(-0.50, len(x_axis)-0.50)
# Out:
# (-0.5, 2.5)

# %%
plt.ylim(0, max(Energy)+50)
# Out:
# (0, 466)

# %%
plt.savefig("Electricity_Energy_Cost_2022.png")
